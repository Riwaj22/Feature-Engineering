# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Normalization is the process of rescaling one or more attributes to the range of 0 to 1. This means that the largest value for each attribute is 1 and the smallest value is 0

# %% [markdown]
# X' = (X-Xmin)/(Xmax-Xmin) where
# Xmax = Maximum value
# Xmin = Minimum value

# %% [markdown]
# Method of Feature Scaling:
#     1. Standard Scaler
#     2. Minmax Scaler
#     3. Robust Scaler
#     4. Normalizer

# %% [markdown]
# StandardScaler: Assumes your data is normally d=istributed within each feature and will scale them such that the distribution is now centered around 0

# %%
from sklearn import preprocessing
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# Normalizer

# %%
df = pd.DataFrame(
    {
        'x1': np.random.randint(-100,100,1000).astype(float),
        'y1': np.random.randint(-80,80,1000).astype(float),
        'z1': np.random.randint(-150,150,1000).astype(float)
    }
)

# %%
df
# Out:
#        x1    y1     z1
# 0    32.0 -31.0    2.0
# 1     4.0 -57.0  -68.0
# 2   -54.0  13.0 -106.0
# 3    67.0 -70.0  -55.0
# 4   -40.0  43.0 -112.0
# ..    ...   ...    ...
# 995   2.0   3.0 -108.0
# 996 -56.0  10.0   39.0
# 997 -19.0 -67.0  -45.0
# 998 -86.0   7.0  -18.0
# 999  91.0 -50.0    0.0
#
# [1000 rows x 3 columns]

# %%
scaler = preprocessing.Normalizer()
scaled_df = scaler.fit_transform(df)
scaled_df = pd.DataFrame(scaled_df, columns=df.columns)

# %%
scaled_df
# Out:
#            x1        y1        z1
# 0    0.717518 -0.695095  0.044845
# 1    0.045035 -0.641747 -0.765593
# 2   -0.451239  0.108632 -0.885766
# 3    0.601338 -0.628264 -0.493636
# 4   -0.316297  0.340019 -0.885631
# ..        ...       ...       ...
# 995  0.018508  0.027762 -0.999443
# 996 -0.811935  0.144988  0.565455
# 997 -0.229149 -0.808050 -0.542720
# 998 -0.975699  0.079417 -0.204216
# 999  0.876419 -0.481549  0.000000
#
# [1000 rows x 3 columns]

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10,10))

ax1 = fig.add_subplot(121, projection = '3d')
ax2 = fig.add_subplot(122, projection = '3d')
ax1.scatter(df['x1'], df['y1'], df['z1'])
ax2.scatter(scaled_df['x1'], scaled_df['y1'], scaled_df['z1'])
